# %% [markdown]
# ## 1. Tensorflow train neural network for Iris dataset
# * source: https://www.tensorflow.org/get_started/estimator
# * network with 3 layers

# %%
# !rm -r ../output/iris_model
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os
from six.moves.urllib.request import urlopen

import numpy as np
import tensorflow as tf

# Data sets
IRIS_TRAINING = "../data/iris/tensorflow_iris_training2.csv"
IRIS_TRAINING_URL = "http://download.tensorflow.org/data/iris_training.csv"

IRIS_TEST = "../data/iris/tensorflow_iris_test2.csv"
IRIS_TEST_URL = "http://download.tensorflow.org/data/iris_test.csv"

# If the training and test sets aren't stored locally, download them.
if not os.path.exists(IRIS_TRAINING):
    raw = urlopen(IRIS_TRAINING_URL).read()
    with open(IRIS_TRAINING, "wb") as f:
        f.write(raw)

if not os.path.exists(IRIS_TEST):
    raw = urlopen(IRIS_TEST_URL).read()
    with open(IRIS_TEST, "wb") as f:
        f.write(raw)

# Load datasets.
training_set = tf.contrib.learn.datasets.base.load_csv_with_header(
  filename=IRIS_TRAINING,
  target_dtype=np.int,
  features_dtype=np.float32)
test_set = tf.contrib.learn.datasets.base.load_csv_with_header(
  filename=IRIS_TEST,
  target_dtype=np.int,
  features_dtype=np.float32)

# Specify that all features have real-value data
feature_columns = [tf.feature_column.numeric_column("x", shape=[4])]

# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
                                      hidden_units=[10, 20, 10],
                                      n_classes=3,
                                      model_dir="../output/iris_model")
# Define the training inputs
train_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": np.array(training_set.data)},
  y=np.array(training_set.target),
  num_epochs=None,
  shuffle=True)

# fix from here: https://github.com/tensorflow/tensorflow/issues/11812
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
with tf.Session(config=config) as sess:

    # Train model.
    classifier.train(input_fn=train_input_fn, steps=2000)

    # Define the test inputs
    test_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": np.array(test_set.data)},
      y=np.array(test_set.target),
      num_epochs=1,
      shuffle=False)

    # Evaluate accuracy.
    accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]

    print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

    # Classify two new flower samples.
    new_samples = np.array(
      [[6.4, 3.2, 4.5, 1.5],
       [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": new_samples},
      num_epochs=1,
      shuffle=False)

    predictions = list(classifier.predict(input_fn=predict_input_fn))
    predicted_classes = [p["classes"].astype(int)[0] for p in predictions]

    print(
      "New Samples, Class Predictions:    {}\n"
      .format(predicted_classes))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_id': 0, '_log_step_count_steps': 100, '_master': '', '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002174E6E7E48>, '_save_checkpoints_steps': None, '_service': None, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_session_config': None, '_num_ps_replicas': 0, '_is_chief': True, '_model_dir': '../output/iris_model', '_save_checkpoints_secs': 600, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_tf_random_seed': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from ../output/iris_model\model.ckpt-2000
# INFO:tensorflow:Saving checkpoints for 2001 into ../output/iris_model\model.ckpt.
# INFO:tensorflow:loss = 8.24665, step = 2001
# INFO:tensorflow:global_step/sec: 221.138
# INFO:tensorflow:loss = 6.5544, step = 2101 (0.458 sec)
# INFO:tensorflow:global_step/sec: 227.706
# INFO:tensorflow:loss = 3.23373, step = 2201 (0.437 sec)
# INFO:tensorflow:global_step/sec: 219.195
# INFO:tensorflow:loss = 4.25297, step = 2301 (0.457 sec)
# INFO:tensorflow:global_step/sec: 229.802
# INFO:tensorflow:loss = 8.45947, step = 2401 (0.434 sec)
# INFO:tensorflow:global_step/sec: 221.632
# INFO:tensorflow:loss = 2.26638, step = 2501 (0.454 sec)
# INFO:tensorflow:global_step/sec: 217.76
# INFO:tensorflow:loss = 4.63731, step = 2601 (0.458 sec)
# INFO:tensorflow:global_step/sec: 210.404
# INFO:tensorflow:loss = 4.6854, step = 2701 (0.472 sec)
# INFO:tensorflow:global_step/sec: 206.442
# INFO:tensorflow:loss = 5.66897, step = 2801 (0.485 sec)
# INFO:tensorflow:global_step/sec: 244.521
# INFO:tensorflow:loss = 10.1272, step = 2901 (0.409 sec)
# INFO:tensorflow:global_step/sec: 233.578
# INFO:tensorflow:loss = 2.50404, step = 3001 (0.428 sec)
# INFO:tensorflow:global_step/sec: 225.133
# INFO:tensorflow:loss = 4.30091, step = 3101 (0.443 sec)
# INFO:tensorflow:global_step/sec: 200.672
# INFO:tensorflow:loss = 1.44287, step = 3201 (0.497 sec)
# INFO:tensorflow:global_step/sec: 218.234
# INFO:tensorflow:loss = 1.68837, step = 3301 (0.460 sec)
# INFO:tensorflow:global_step/sec: 195.175
# INFO:tensorflow:loss = 1.41196, step = 3401 (0.510 sec)
# INFO:tensorflow:global_step/sec: 201.078
# INFO:tensorflow:loss = 8.33247, step = 3501 (0.502 sec)
# INFO:tensorflow:global_step/sec: 238.029
# INFO:tensorflow:loss = 6.57701, step = 3601 (0.416 sec)
# INFO:tensorflow:global_step/sec: 231.401
# INFO:tensorflow:loss = 0.702738, step = 3701 (0.432 sec)
# INFO:tensorflow:global_step/sec: 223.619
# INFO:tensorflow:loss = 3.56078, step = 3801 (0.447 sec)
# INFO:tensorflow:global_step/sec: 213.107
# INFO:tensorflow:loss = 1.50624, step = 3901 (0.468 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ../output/iris_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.72293.
# INFO:tensorflow:Starting evaluation at 2018-02-14-13:38:06
# INFO:tensorflow:Restoring parameters from ../output/iris_model\model.ckpt-4000
# INFO:tensorflow:Finished evaluation at 2018-02-14-13:38:07
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.966667, average_loss = 0.0840352, global_step = 4000, loss = 2.52106
#
# Test Accuracy: 0.966667
#
# INFO:tensorflow:Restoring parameters from ../output/iris_model\model.ckpt-4000
# New Samples, Class Predictions:    [1, 1]

# %% [markdown]
# ## 2. Scikit vs. Tensorflow classifiers
# ## 2.1. Scikit train classifiers and plot - only on 2 out of 4 dimensions

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets


def make_meshgrid(x, y, h=.02):
    """Create a mesh of points to plot in

    Parameters
    ----------
    x: data to base x-axis meshgrid on
    y: data to base y-axis meshgrid on
    h: stepsize for meshgrid, optional

    Returns
    -------
    xx, yy : ndarray
    """
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    return xx, yy


def plot_contours(ax, clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out


# import some data to play with
iris = datasets.load_iris()
# Take the first two features. We could avoid this by using a two-dim dataset
X = iris.data[:, :2]
y = iris.target

# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter
models = (svm.SVC(kernel='linear', C=C),
          svm.LinearSVC(C=C),
          svm.SVC(kernel='rbf', gamma=0.7, C=C),
          svm.SVC(kernel='poly', degree=3, C=C))
models = (clf.fit(X, y) for clf in models)

# title for the plots
titles = ('SVC with linear kernel',
          'LinearSVC (linear kernel)',
          'SVC with RBF kernel',
          'SVC with polynomial (degree 3) kernel')

# Set-up 2x2 grid for plotting.
fig, sub = plt.subplots(2, 2)
plt.subplots_adjust(wspace=0.4, hspace=0.4)

X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)

for clf, title, ax in zip(models, titles, sub.flatten()):
    plot_contours(ax, clf, xx, yy,
                  cmap=plt.cm.coolwarm, alpha=0.8)
    ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xlabel('Sepal length')
    ax.set_ylabel('Sepal width')
    ax.set_xticks(())
    ax.set_yticks(())
    ax.set_title(title)

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# ## 2.2. Tensorflow train neural network only on 2 dimensions, and plot, to compare against scikit learn classifiers
# only 2 dimensions are used, so the accuracy is not great

# %%
# !rm -r ../output/iris_model
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Specify that all features have real-value data
feature_columns = [tf.feature_column.numeric_column("x", shape=[2])]

# Build 3 layer DNN with 10, 20, 10 units respectively.
classifier = tf.estimator.DNNClassifier(feature_columns=feature_columns,
                                      hidden_units=[10, 20, 10],
                                      n_classes=3,
                                      model_dir="../output/iris_model")
# Define the training inputs
train_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": np.array(training_set.data).T[:2].T},
  y=np.array(training_set.target),
  num_epochs=None,
  shuffle=True)

# Train model.
classifier.train(input_fn=train_input_fn, steps=2000)

# Define the test inputs
test_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": np.array(test_set.data).T[:2].T},
  y=np.array(test_set.target),
  num_epochs=1,
  shuffle=False)

# Evaluate accuracy.
accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]

print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

# Classify two new flower samples.
new_samples = np.array(
  [[6.4, 3.2, 4.5, 1.5],
   [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
predict_input_fn = tf.estimator.inputs.numpy_input_fn(
  x={"x": new_samples.T[:2].T},
  num_epochs=1,
  shuffle=False)

predictions = list(classifier.predict(input_fn=predict_input_fn))
predicted_classes = [p["classes"].astype(int)[0] for p in predictions]

print(
  "New Samples, Class Predictions:    {}\n"
  .format(predicted_classes))
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_task_id': 0, '_log_step_count_steps': 100, '_master': '', '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000021753EC7DD8>, '_save_checkpoints_steps': None, '_service': None, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_session_config': None, '_num_ps_replicas': 0, '_is_chief': True, '_model_dir': '../../output/iris_model', '_save_checkpoints_secs': 600, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_tf_random_seed': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ../../output/iris_model\model.ckpt.
# INFO:tensorflow:loss = 146.563, step = 1
# INFO:tensorflow:global_step/sec: 220.245
# INFO:tensorflow:loss = 56.1451, step = 101 (0.456 sec)
# INFO:tensorflow:global_step/sec: 201.483
# INFO:tensorflow:loss = 61.0422, step = 201 (0.495 sec)
# INFO:tensorflow:global_step/sec: 220.651
# INFO:tensorflow:loss = 52.9508, step = 301 (0.453 sec)
# INFO:tensorflow:global_step/sec: 212.447
# INFO:tensorflow:loss = 60.162, step = 401 (0.473 sec)
# INFO:tensorflow:global_step/sec: 229.802
# INFO:tensorflow:loss = 54.085, step = 501 (0.434 sec)
# INFO:tensorflow:global_step/sec: 218.237
# INFO:tensorflow:loss = 52.5627, step = 601 (0.457 sec)
# INFO:tensorflow:global_step/sec: 212.2
# INFO:tensorflow:loss = 44.5098, step = 701 (0.472 sec)
# INFO:tensorflow:global_step/sec: 209.525
# INFO:tensorflow:loss = 56.3796, step = 801 (0.476 sec)
# INFO:tensorflow:global_step/sec: 208.213
# INFO:tensorflow:loss = 48.2222, step = 901 (0.481 sec)
# INFO:tensorflow:global_step/sec: 224.626
# INFO:tensorflow:loss = 47.1292, step = 1001 (0.444 sec)
# INFO:tensorflow:global_step/sec: 248.711
# INFO:tensorflow:loss = 52.2724, step = 1101 (0.403 sec)
# INFO:tensorflow:global_step/sec: 245.05
# INFO:tensorflow:loss = 46.2391, step = 1201 (0.407 sec)
# INFO:tensorflow:global_step/sec: 206.062
# INFO:tensorflow:loss = 51.1721, step = 1301 (0.486 sec)
# INFO:tensorflow:global_step/sec: 201.158
# INFO:tensorflow:loss = 57.8765, step = 1401 (0.497 sec)
# INFO:tensorflow:global_step/sec: 209.086
# INFO:tensorflow:loss = 47.3803, step = 1501 (0.479 sec)
# INFO:tensorflow:global_step/sec: 235.29
# INFO:tensorflow:loss = 52.0126, step = 1601 (0.424 sec)
# INFO:tensorflow:global_step/sec: 231.346
# INFO:tensorflow:loss = 50.041, step = 1701 (0.433 sec)
# INFO:tensorflow:global_step/sec: 240.903
# INFO:tensorflow:loss = 46.4046, step = 1801 (0.415 sec)
# INFO:tensorflow:global_step/sec: 222.621
# INFO:tensorflow:loss = 44.5761, step = 1901 (0.448 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ../../output/iris_model\model.ckpt.
# INFO:tensorflow:Loss for final step: 46.1641.
# INFO:tensorflow:Starting evaluation at 2018-02-14-13:38:44
# INFO:tensorflow:Restoring parameters from ../../output/iris_model\model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2018-02-14-13:38:45
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.766667, average_loss = 0.445284, global_step = 2000, loss = 13.3585
#
# Test Accuracy: 0.766667
#
# INFO:tensorflow:Restoring parameters from ../../output/iris_model\model.ckpt-2000
# New Samples, Class Predictions:    [2, 1]

# %%
# Classify two new flower samples.
new_samples = np.array(
    [[6.4, 3.2, 4.5, 1.5],
     [5.8, 3.1, 5.0, 1.7]], dtype=np.float32)
predict_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": new_samples.T[:2].T},
    num_epochs=1,
    shuffle=False)

predictions = list(classifier.predict(input_fn=predict_input_fn))
predicted_classes = [p["classes"].astype(int)[0] for p in predictions]

print(
    "New Samples, Class Predictions:    {}\n"
    .format(predicted_classes))
# Out:
# INFO:tensorflow:Restoring parameters from ../../output/iris_model\model.ckpt-2000
# New Samples, Class Predictions:    [2, 1]

# %%
def plot_contours_nn(ax, clf, xx, yy, **params):
    """Plot the decision boundaries for a classifier.

    Parameters
    ----------
    ax: matplotlib axes object
    clf: a classifier
    xx: meshgrid ndarray
    yy: meshgrid ndarray
    params: dictionary of params to pass to contourf, optional
    """
    predict_input_fn = tf.estimator.inputs.numpy_input_fn(
      #x={"x": np.c_[xx.ravel(), yy.ravel(), np.repeat(4.5,len(xx.ravel())), np.repeat(1.5,len(xx.ravel()))]},
      x={"x": np.c_[xx.ravel(), yy.ravel()]},
      num_epochs=1,
      shuffle=False)
    predictions = list(classifier.predict(input_fn=predict_input_fn))
    predicted_classes = [p["classes"].astype(int)[0] for p in predictions]
    Z = np.array(predicted_classes)
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    
    return out
# %matplotlib inline
import matplotlib.pylab as plt
#plt.figure()
# Set-up 2x2 grid for plotting.
fig, ax = plt.subplots(1, 1)
plt.subplots_adjust(wspace=0.4, hspace=0.4)
X=np.array(training_set.data)
y=np.array(training_set.target)
X0, X1 = X[:, 0], X[:, 1]
xx, yy = make_meshgrid(X0, X1)

plot_contours_nn(ax, classifier, xx, yy,
          cmap=plt.cm.coolwarm, alpha=0.8)
ax.scatter(X0, X1, c=y, cmap=plt.cm.coolwarm, s=20, edgecolors='k')
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_xlabel('Sepal length')
ax.set_ylabel('Sepal width')
ax.set_xticks(())
ax.set_yticks(())
ax.set_title('Neural Network')
# Out:
# INFO:tensorflow:Restoring parameters from ../../output/iris_model\model.ckpt-2000
# Text(0.5,1,'Neural Network')
